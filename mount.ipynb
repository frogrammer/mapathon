# %%
dbutils.fs.mount(
  source = "wasbs://dev@frogrammer.blob.core.windows.net",
  mount_point = "/mnt/dev",
  extra_configs = {'fs.azure.account.key.frogrammer.blob.core.windows.net':'7XIFAynizwaStnKe4iSQVQrv+XSikBKzB1stZ48mkt17TJez0Gur2qApfVtaRy64e4nyRtGL3lOsvSMVvsOXiQ=='})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: True</div>

# %%
dbutils.fs.unmount('/mnt/dev')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/dev has been unmounted.
# Out[5]: True</div>
